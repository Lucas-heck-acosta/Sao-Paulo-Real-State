# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/kaggle/input/sao-paulo-real-estate-sale-rent-april-2019/sao-paulo-properties-april-2019.csv")

# %%
df.head()

# %%
df['Negotiation Type']

# %%
df['Price'].mean()

# %%
df_rent = df.loc[df['Negotiation Type'] == 'rent']
df_buy = df.loc[df['Negotiation Type'] == 'sale']

# %%
df_rent['Price'].mean(), df_buy['Price'].mean()

# %%
df_rent.describe()

# %%
df_rent.info()

# %%
df_rent.isnull().sum()

# %%
df_rent.duplicated().sum()

# %%
dataplot = sns.heatmap(df_rent.corr(numeric_only=True), cmap='BuPu', annot=True)
plt.title('Data correlation', fontsize=18)
plt.show()

# %%
df_rent = df_rent.drop_duplicates()
